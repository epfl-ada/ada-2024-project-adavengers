# %%
# %load_ext autoreload
# %autoreload 2

import pathlib

from src.data.load_population_data import PopulationInformationDataLoader

# %%
data_dir_path = pathlib.Path("../../data")
src_path = data_dir_path / 'correlates2-6.csv'

# %%
loader = PopulationInformationDataLoader(src_path)
res = loader.get_population_infos_by_states()
res = res[res['year'] != 2012]
res
# Out:
#       year          state  pctpop25to44  pctpop45to64  pctpopover65  \
# 104   2004         Alaska      0.277505      0.255434      0.063534
# 108   2008         Alaska      0.289072      0.266431      0.073135
# 116   2016         Alaska      0.289000      0.255000      0.102000
# 225   2004        Alabama      0.286930      0.242787      0.131979
# 229   2008        Alabama      0.254334      0.254334      0.135998
# ...    ...            ...           ...           ...           ...
# 6037  2008  West Virginia      0.255799      0.279575      0.154902
# 6045  2016  West Virginia      0.240000      0.278000      0.188000
# 6154  2004        Wyoming      0.256237      0.276565      0.120040
# 6158  2008        Wyoming      0.251515      0.269721      0.120163
# 6166  2016        Wyoming      0.261000      0.256000      0.150000
#
#       pop_annual
# 104     659286.0
# 108     687455.0
# 116          NaN
# 225    4530729.0
# 229    4718206.0
# ...          ...
# 6037   1840310.0
# ...
